# %% [markdown]
# # 🟡 Portfolio Exercise 3: Automated Technical Blog CMS (LCEL & Streaming)
#
# ### 💼 Business Case & Real-World Context:
# Content marketing is crucial for developer outreach, but writing high-quality technical blog posts is incredibly time-consuming. Modern **CMS Writing Assistants** leverage LLMs to expand high-level technical notes into fully formed markdown posts. Because generating long posts takes time, production apps **stream** the output in real-time to the user interface, avoiding a sluggish "loading spinner" screen.
#
# ### 💡 Portfolio Showcase Tip:
# > **Why recruiters care:** Constructing pipelines with **LangChain Expression Language (LCEL)** and incorporating token-by-token **streaming** are core requirements for advanced AI developer roles. Streaming demonstrates your readiness to build highly responsive, production-ready web interfaces.
#
# ---

# %% [markdown]
# ### 🎯 Your Challenge:
# 1. **Define the Components**:
#    - **Prompt**: Design a prompt instructing a technical content writer to draft a structured Markdown blog post on a given `{topic}` tailored for a specific `{target_audience}`. Include headings, a brief introduction, bullet points, and a summary.
#    - **Model**: Set up `ChatGoogleGenerativeAI(model="gemini-1.5-flash")` with `temperature=0.7` for fluent, engaging writing.
#    - **Output Parser**: Import and initialize `StrOutputParser` to automatically extract the clean generated string from the response metadata.
# 2. **Construct the LCEL Chain**: Hook the prompt, model, and parser together using the pipe operator (`|`).
# 3. **Execute Both Execution Modes**:
#    - **Mode 1 (.invoke)**: Run standard synchronous execution to generate a quick post about *"Why developers should use Git Rebase instead of Merge"* for junior developers.
#    - **Mode 2 (.stream)**: Run streaming execution to generate a post about *"Introduction to Serverless Databases"* for system architects. Print each chunk to stdout in real-time as it arrives, creating a smooth visual typing effect.

# %%
import os
import sys
import time
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
# Load environment variables
load_dotenv()

# Initialize model
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0.7)

# %%
# TODO: Define your ChatPromptTemplate and StrOutputParser
# 1. Create a prompt template accepting variables {topic} and {target_audience}
# 2. Instantiate the StrOutputParser

prompt = None
output_parser = None  # Your code here

# %%
# TODO: Assemble the pipeline using LangChain Expression Language (LCEL)
# Formula: prompt | llm | output_parser

chain = None  # Your code here

# %%
# TODO: Challenge part 1 - Synchronously generate and print a full blog post
# Topic: "Why developers should use Git Rebase instead of Merge"
# Target Audience: "Junior Developers"

# Your code here

# %%
# TODO: Challenge part 2 - Stream the generation in real-time token-by-token
# Topic: "Introduction to Serverless Databases"
# Target Audience: "System Architects"
# Hint: Iterate over 'chain.stream(...)'. Use sys.stdout.write() and sys.stdout.flush() to print smooth text.

# Your code here
