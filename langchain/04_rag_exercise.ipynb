# %% [markdown]
# # 🔴 Portfolio Exercise 4: Corporate HR Policy Q&A System (RAG)
#
# ### 💼 Business Case & Real-World Context:
# Employees waste countless hours searching dense corporate manuals for policies on medical benefits, time off, and stipends. Standard LLMs cannot answer these questions because internal policies are private. By implementing **Retrieval-Augmented Generation (RAG)**, we index internal documents in a vector store and retrieve relevant passages dynamically to answer employee questions with 100% factual accuracy grounded in company documents.
#
# ### 💡 Portfolio Showcase Tip:
# > **Why recruiters care:** RAG is one of the most high-demand skills in AI engineering. Building a functional RAG pipeline using semantic embeddings, vector indexing, and context-constrained prompt chaining proves you can build corporate-compliant systems that eliminate hallucinations.
#
# ---

# %% [markdown]
# ### 🎯 Your Challenge:
# 1. **Define Internal Corporate Policy**: We provide realistic HR benefits handbook paragraphs.
# 2. **Implement Chunking**: Use `RecursiveCharacterTextSplitter` to break documents down into highly retrievable chunks of 200 characters with an overlap of 20 characters.
# 3. **Build Semantic Index**: Instantiate `GoogleGenerativeAIEmbeddings(model="models/embedding-001")` and store the embedded text chunks inside an in-memory `FAISS` vector store.
# 4. **Assemble the LCEL RAG Chain**: Create a custom context-aware prompt template and chain it together using LangChain's core `Runnable` standards. The chain should take a question, fetch top matching passages, format them as context, and return Gemini's grounded answer.
# 5. **Execute a Query**: Ask: *"How much is the remote work office stipend and when does PTO expire?"* and print the response.

# %%
# Install dependencies if needed:
# %pip install faiss-cpu langchain-community langchain-google-genai

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# Load environment variables
load_dotenv()

# %%
# 1. Mock Enterprise HR Database Documents
hr_handbook = [
    "Antigravity Corp offers employees a remote-work equipment stipend of $500 annually to set up ergonomic workspaces.",
    "Paid Time Off (PTO) accumulates at a rate of 1.5 days per month, capping at 18 days per year. Unused PTO expires on December 31st.",
    "Medical benefits cover 100% of preventative care premiums. Specialty care requires a flat $25 copay under the Gold Health Plan.",
    "Paid Parental Leave offers new parents 12 weeks of fully paid leave, applicable to childbirth, adoption, or foster care placements.",
    "Professional development funds support up to $2,000 yearly for courses, industry conferences, and approved certifications."
]

# %%
# TODO: Step 2 - Chunk the documents
# Initialize RecursiveCharacterTextSplitter (chunk_size=200, chunk_overlap=20)
# Split the 'hr_handbook' strings into Documents using .create_documents(...)

text_splitter = None
chunks = None  # Your code here

# %%
# TODO: Step 3 - Generate Embeddings and build the FAISS Vector Database
# 1. Initialize GoogleGenerativeAIEmbeddings (using model="models/embedding-001")
# 2. Build FAISS index from documents: FAISS.from_documents(chunks, embeddings)

embeddings = None
vectorstore = None  # Your code here

# %%
# TODO: Step 4 - Construct the custom LCEL RAG Chain
# 1. Extract a retriever interface from the vectorstore (fetching top 2 matched chunks)
# 2. Define a ChatPromptTemplate with System instructions explaining the model MUST ONLY
#    use the provided {context} and say 'I don't know' if the context does not answer the question.
# 3. Set up Gemini model (model='gemini-1.5-flash', temperature=0.0)
# 4. Assemble the LCEL chain. Use format_docs to join retrieved passages.

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

retriever = None
prompt = None
llm = None
rag_chain = None  # Your code here

# %%
# TODO: Step 5 - Test the RAG QA Engine with employee query
query = "How much is the remote work office stipend and when does PTO expire?"

# Your code here
